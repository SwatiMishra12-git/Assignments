# %%
#Question 1
import numpy as np

# Method 1: Using np.array()
array1 = np.array([[1, 2, 3], [4, 5, 6]])
print("Method 1: Using np.array()")
print(array1)

# Method 2: Using np.full()
array2 = np.full((2, 3), [[1, 2, 3], [4, 5, 6]])
print("\nMethod 2: Using np.full()")
print(array2)

# Method 3: Using np.ones() and modifying values
array3 = np.ones((2, 3))  # Create an array filled with ones
array3[0] = [1, 2, 3]
array3[1] = [4, 5, 6]
print("\nMethod 3: Using np.ones() and modifying values")
print(array3)
# Out:
# Method 1: Using np.array()
# [[1 2 3]
#  [4 5 6]]
#
# Method 2: Using np.full()
# [[1 2 3]
#  [4 5 6]]
#
# Method 3: Using np.ones() and modifying values
# [[1. 2. 3.]
#  [4. 5. 6.]]

# %%
#Question 2
import numpy as np

# Generate 100 evenly spaced numbers between 1 and 10
array_1d = np.linspace(1, 10, 100)

# Reshape it into a 2D array of shape (10, 10)
array_2d = array_1d.reshape(10, 10)

print("1D Array:")
print(array_1d)

print("\nReshaped 2D Array (10x10):")
print(array_2d)
# Out:
# 1D Array:
# [ 1.          1.09090909  1.18181818  1.27272727  1.36363636  1.45454545
#   1.54545455  1.63636364  1.72727273  1.81818182  1.90909091  2.
#   2.09090909  2.18181818  2.27272727  2.36363636  2.45454545  2.54545455
#   2.63636364  2.72727273  2.81818182  2.90909091  3.          3.09090909
#   3.18181818  3.27272727  3.36363636  3.45454545  3.54545455  3.63636364
#   3.72727273  3.81818182  3.90909091  4.          4.09090909  4.18181818
#   4.27272727  4.36363636  4.45454545  4.54545455  4.63636364  4.72727273
#   4.81818182  4.90909091  5.          5.09090909  5.18181818  5.27272727
#   5.36363636  5.45454545  5.54545455  5.63636364  5.72727273  5.81818182
#   5.90909091  6.          6.09090909  6.18181818  6.27272727  6.36363636
#   6.45454545  6.54545455  6.63636364  6.72727273  6.81818182  6.90909091
#   7.          7.09090909  7.18181818  7.27272727  7.36363636  7.45454545
#   7.54545455  7.63636364  7.72727273  7.81818182  7.90909091  8.
# ...

# %%
#Question 3

# %% [markdown]
# Part 1: np.array vs. np.asarray vs. np.asanyarray
#
# These three functions are used to create NumPy arrays, but they behave slightly differently.
#
# Function	Description
# **np.array()**	Always creates a new NumPy array from the input data.	Creates a copy by default.
#
# **np.asarray()**	Converts the input into an array but does not copy if it's already a NumPy array.	Avoids unnecessary duplication.
#
# **np.asanyarray()**	Similar to np.asarray(), but it preserves subclass types (like matrix).	Keeps subclass types intact.

# %%
#Example
import numpy as np

lst = [1, 2, 3]
arr = np.array(lst)  # Always creates a new array
arr2 = np.asarray(arr)  # Does NOT create a copy if input is already an array
arr3 = np.asanyarray(arr)  # Same as asarray for standard arrays

print(arr is arr2)  # True, because no new copy was made
print(arr is arr3)  # True, for the same reason

#If we use a NumPy matrix instead of an array
matrix = np.matrix([[1, 2], [3, 4]])
arr4 = np.asarray(matrix)
arr5 = np.asanyarray(matrix)

print(type(arr4))  # <class 'numpy.ndarray'>
print(type(arr5))  # <class 'numpy.matrix'>  (Preserves matrix type)
# Out:
# True
# True
# <class 'numpy.ndarray'>
# <class 'numpy.matrix'>

# %% [markdown]
# Part 2: Deep Copy vs. Shallow Copy
#
# **Shallow Copy**: Only copies references to the original object; changes in the copy affect the original.
#
# **Deep Copy**: Creates a completely new copy of the object; changes in the copy do not affect the original.

# %%
#Example
import numpy as np
import copy

arr = np.array([[1, 2, 3], [4, 5, 6]])

# Shallow Copy
shallow = arr.view()  # Creates a new view, but data is shared
shallow[0, 0] = 99
print("Original array after modifying shallow copy:\n", arr)  # Original array changes!

# Deep Copy
arr = np.array([[1, 2, 3], [4, 5, 6]])  # Reset array
deep = copy.deepcopy(arr)  # Creates a completely independent copy
deep[0, 0] = 99
print("\nOriginal array after modifying deep copy:\n", arr)  # Original remains unchanged
# Out:
# Original array after modifying shallow copy:
#  [[99  2  3]
#  [ 4  5  6]]
#
# Original array after modifying deep copy:
#  [[1 2 3]
#  [4 5 6]]

# %%
#Question 4
import numpy as np

# Generate a 3x3 array with random floats between 5 and 20
random_array = np.random.uniform(5, 20, size=(3, 3))

# Round each element to 2 decimal places
rounded_array = np.round(random_array, 2)

# Print the results
print("Original 3x3 Random Array:\n", random_array)
print("\nRounded 3x3 Array:\n", rounded_array)
# Out:
# Original 3x3 Random Array:
#  [[15.33317708 10.26181379  6.79564176]
#  [19.77341856 19.52562982 17.55787887]
#  [11.00859106 11.90990752 14.73410069]]
#
# Rounded 3x3 Array:
#  [[15.33 10.26  6.8 ]
#  [19.77 19.53 17.56]
#  [11.01 11.91 14.73]]

# %%
#Question 5
import numpy as np

# Generate a 5x6 array with random integers between 1 and 10
random_array = np.random.randint(1, 11, size=(5, 6))

# Extract even numbers
even_numbers = random_array[random_array % 2 == 0]

# Extract odd numbers
odd_numbers = random_array[random_array % 2 != 0]

# Print the results
print("Original 5x6 Random Array:\n", random_array)
print("\nEven Numbers:", even_numbers)
print("\nOdd Numbers:", odd_numbers)
# Out:
# Original 5x6 Random Array:
#  [[ 4  1  9  2  7  5]
#  [ 4  5  4  8  1  1]
#  [ 3  2 10  4  2  7]
#  [ 1  6  9  2  2  7]
#  [ 8  2  4 10  4  4]]
#
# Even Numbers: [ 4  2  4  4  8  2 10  4  2  6  2  2  8  2  4 10  4  4]
#
# Odd Numbers: [1 9 7 5 5 1 1 3 7 1 9 7]

# %%
#Question 6
import numpy as np

# Create a 3x3x3 NumPy array with random integers between 1 and 10
array_3d_1 = np.random.randint(1, 11, size=(3, 3, 3))
array_3d_2 = np.random.randint(1, 11, size=(3, 3, 3))

# Find the indices of the max values along each depth level (axis=2)
max_indices = np.argmax(array_3d_1, axis=2)

# Perform element-wise multiplication between the two arrays
multiplied_array = array_3d_1 * array_3d_2

# Print the results
print("First 3D Array:\n", array_3d_1)
print("\nIndices of Maximum Values Along Depth Axis:\n", max_indices)
print("\nSecond 3D Array:\n", array_3d_2)
print("\nElement-wise Multiplication Result:\n", multiplied_array)
# Out:
# First 3D Array:
#  [[[ 1  9 10]
#   [ 2  9 10]
#   [ 8  6  8]]
#
#  [[ 6  8  8]
#   [10  7  1]
#   [ 8  9  3]]
#
#  [[ 8 10  4]
#   [ 5  8  4]
#   [ 8  4  4]]]
#
# Indices of Maximum Values Along Depth Axis:
#  [[2 2 0]
#  [1 0 1]
#  [1 1 0]]
#
# Second 3D Array:
#  [[[ 1  2  3]
#   [ 8  1  1]
#   [ 1  2  8]]
#
#  [[ 7  1  3]
#   [ 1  3  9]
#   [ 3  8 10]]
#
#  [[ 5  9  8]
#   [ 7  2 10]
#   [ 2  3  6]]]
#
# Element-wise Multiplication Result:
#  [[[ 1 18 30]
#   [16  9 10]
#   [ 8 12 64]]
#
#  [[42  8 24]
#   [10 21  9]
#   [24 72 30]]
#
#  [[40 90 32]
#   [35 16 40]
#   [16 12 24]]]

# %%
#Question 7
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-cb73f512-bbbd-4091-b42e-a5c4ffdb5c2a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb73f512-bbbd-4091-b42e-a5c4ffdb5c2a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded["People Data.csv"]))
print(df.head)
# Out:
# <bound method NDFrame.head of      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    27-01-2014
# 1    fergusonkatherine@example.net                    NaN    26-07-1931
# ...

# %%
df['Phone'] = df['Phone'].astype(str).str.replace(r'\D', '', regex=True)  # Remove non-digits
df['Phone'] = pd.to_numeric(df['Phone'], errors='coerce')  # Convert to numeric (NaN if conversion fails)

# Display the cleaned dataset and data types
print("Cleaned Data:\n", df.head())  # First 5 rows
print("\nData Types and Attributes:")
print(df.info())  # Column names, data types, and missing values
# Out:
# Cleaned Data:
#     Index          User Id First Name Last Name  Gender  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                            Email         Phone Date of birth  \
# 0            pwarner@example.org  8.571398e+09    27-01-2014
# 1  fergusonkatherine@example.net           NaN    26-07-1931
# 2            fhoward@example.org  5.997821e+09    25-11-2013
# 3          zjohnston@example.com           NaN    17-11-2012
# 4               elin@example.net  3.904172e+13    15-04-1923
#
#                   Job Title  Salary
# 0         Probation officer   90000
# 1                    Dancer   80000
# 2                      Copy   50000
# 3  Counselling psychologist   65000
# 4       Biomedical engineer  100000
#
# ...

# %%
#Question 8
import pandas as pd

# Step 1: Upload the CSV file to the Colab environment
from google.colab import files
uploaded = files.upload()

# Step 2: Read the first row to get the column names
df_header = pd.read_csv('People Data.csv', nrows=0)

# Step 3: Skip the first 50 rows and read the rest of the file
df = pd.read_csv('People Data.csv', skiprows=50, header=None)

# Step 4: Assign the column names from the first DataFrame
df.columns = df_header.columns

# Step 5: Only read the columns: 'Last Name', 'Gender', 'Email', 'Phone', and 'Salary' from the file
filtered_df = df[['Last Name', 'Gender', 'Email', 'Phone', 'Salary']]

# Step 6: Rename the columns (if needed)
filtered_df.rename(columns={
    'Last Name': 'Surname',
    'Gender': 'Sex',
    'Email': 'Email Address',
    'Phone': 'Contact Number',
    'Salary': 'Income'
}, inplace=True)

# Step 7: Display the first 10 rows of the renamed dataset
print(filtered_df.head(10))

# Step 8: Extract the 'Income' column as a Series and display its last 5 values
salary_series = filtered_df['Income']
print(salary_series.tail(5))
# Out:
#      <input type="file" id="files-be5d6e9b-859b-4f5f-a803-f655e81dfc7f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be5d6e9b-859b-4f5f-a803-f655e81dfc7f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Question 9
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-6768b49a-dd65-43e6-b75e-cb6bafe9b38e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6768b49a-dd65-43e6-b75e-cb6bafe9b38e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df1=pd.read_csv('People Data.csv')
filtered_df = df1[(df1['Last Name'] == 'Duke') &
                             (df1['Gender'] == 'Female') &
                             (df1['Salary'] < 85000)]

print(filtered_df)
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 45      46  99A502C175C4EBd     Olivia      Duke  Female
# 210    211  DF17975CC0a0373    Katrina      Duke  Female
# 457    458  dcE1B7DE83c1076      Traci      Duke  Female
# 729    730  c9b482D7aa3e682     Lonnie      Duke  Female
#
#                         Email                   Phone Date of birth  \
# 45        diana26@example.net  001-366-475-8607x04350    13-10-1934
# 210       robin78@example.com            740.434.0212    21-09-1935
# 457  perryhoffman@example.org     +1-903-596-0995x489    11-02-1997
# 729   kevinkramer@example.net            982.692.6257    12-05-2015
#
#            Job Title  Salary
# 45           Dentist   60000
# 210  Producer, radio   50000
# 457        Herbalist   50000
# 729     Nurse, adult   70000

# %%
#Question 10
import pandas as pd
import numpy as np

# Generate a series of 35 random integers between 1 and 6
random_integers = np.random.randint(1, 7, size=35)

# Reshape the series into a 7x5 array
data_array = random_integers.reshape(7, 5)

# Create a DataFrame
df = pd.DataFrame(data_array, columns=['A', 'B', 'C', 'D', 'E'])

# Display the DataFrame
print(df)
# Out:
#    A  B  C  D  E
# 0  2  5  2  5  5
# 1  6  1  5  4  5
# 2  5  2  6  1  5
# 3  4  5  1  3  1
# 4  2  1  1  4  1
# 5  1  6  1  3  3
# 6  5  6  4  1  4

# %%
#Question 11
import pandas as pd
import numpy as np

# Generate the first Series with random numbers ranging from 10 to 50
series1 = pd.Series(np.random.randint(10, 51, size=50))

# Generate the second Series with random numbers ranging from 100 to 1000
series2 = pd.Series(np.random.randint(100, 1001, size=50))

# Create a DataFrame by joining these Series by column
df = pd.DataFrame({'col1': series1, 'col2': series2})

# Display the DataFrame
print(df)
# Out:
#     col1  col2
# 0     20   659
# 1     17   565
# 2     46   336
# 3     29   220
# 4     41   856
# 5     21   674
# 6     17   215
# 7     48   824
# 8     11   660
# 9     36   498
# 10    30   547
# 11    28   218
# 12    45  1000
# 13    30   409
# 14    13   581
# 15    48   721
# 16    35   744
# 17    28   858
# 18    46   462
# 19    30   773
# 20    34   929
# 21    46   314
# 22    46   861
# 23    44   456
# 24    43   974
# 25    16   814
# 26    43   782
# 27    28   830
# 28    17   794
# 29    10   677
# 30    28   464
# 31    38   833
# 32    38   569
# 33    49   510
# 34    43   548
# 35    25   207
# 36    11   350
# 37    10   657
# 38    36   907
# 39    44   428
# 40    16   491
# 41    34   881
# 42    20   309
# 43    29   400
# 44    18   144
# 45    20   317
# 46    17   338
# 47    43   504
# 48    22   477
# 49    28   114

# %%
#Question 12
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-06f45e47-d5e8-4e93-92ac-89b0251be621" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06f45e47-d5e8-4e93-92ac-89b0251be621">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
people_df = pd.read_csv('People Data.csv')
# Delete the 'Email', 'Phone', and 'Date of birth' columns from the dataset
people_df = people_df.drop(columns=['Email', 'Phone', 'Date of birth'])

# Delete rows containing any missing values
people_df = people_df.dropna()

# Print the final output
print(people_df)
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                            Job Title  Salary
# 0                  Probation officer   90000
# 1                             Dancer   80000
# 2                               Copy   50000
# 3           Counselling psychologist   65000
# 4                Biomedical engineer  100000
# ...

# %%
#Question 13
import numpy as np
import matplotlib.pyplot as plt

# Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1
x = np.random.rand(100)
y = np.random.rand(100)

# Create a scatter plot using x and y, setting the color of the points to red and the marker style to 'o'
plt.scatter(x, y, color='red', marker='o', label='Random Points')

# Add a horizontal line at y = 0.5 using a dashed line style and label it as 'y = 0.5'
plt.axhline(y=0.5, color='blue', linestyle='--', label='y = 0.5')

# Add a vertical line at x = 0.5 using a dotted line style and label it as 'x = 0.5'
plt.axvline(x=0.5, color='green', linestyle=':', label='x = 0.5')

# Label the x-axis as 'X-axis' and the y-axis as 'Y-axis'
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Set the title of the plot as 'Advanced Scatter Plot of Random Values'
plt.title('Advanced Scatter Plot of Random Values')

# Display a legend for the scatter plot, the horizontal line, and the vertical line
plt.legend()

# Display the plot
plt.show()

# %%
#Question 14
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create a time-series dataset
date_range = pd.date_range(start='2023-01-01', periods=100, freq='D')
temperature = np.random.uniform(low=15, high=35, size=100)
humidity = np.random.uniform(low=30, high=90, size=100)

data = {'Date': date_range, 'Temperature': temperature, 'Humidity': humidity}
df = pd.DataFrame(data)

# Plotting Temperature and Humidity on the same plot with different y-axes
fig, ax1 = plt.subplots()

# Plot Temperature with left y-axis
ax1.plot(df['Date'], df['Temperature'], 'r-', label='Temperature')
ax1.set_xlabel('Date')
ax1.set_ylabel('Temperature (°C)', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# Create a second y-axis to plot Humidity
ax2 = ax1.twinx()
ax2.plot(df['Date'], df['Humidity'], 'b-', label='Humidity')
ax2.set_ylabel('Humidity (%)', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# Set the title of the plot
plt.title('Temperature and Humidity Over Time')

# Add legends for both y-axes
fig.legend(loc='upper left', bbox_to_anchor=(0.1,0.9))

# Show the plot
plt.show()

# %%
#Question 15 and 16
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Create a NumPy array containing 1000 samples from a normal distribution
data = np.random.normal(loc=0, scale=1, size=1000)

# Plot a histogram of the data with 30 bins
plt.hist(data, bins=30, density=True, alpha=0.6, color='g')

# Overlay a line plot representing the normal distribution's probability density function (PDF)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = stats.norm.pdf(x, 0, 1)
plt.plot(x, p, 'k', linewidth=2)

# Label the x-axis as 'Value' and the y-axis as 'Frequency/Probability'
plt.xlabel('Value')
plt.ylabel('Frequency/Probability')

# Set the title of the plot as 'Histogram with PDF Overlay'
plt.title('Histogram with PDF Overlay')

# Display the plot
plt.show()

# %%
#Question 17
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generate two random arrays
x = np.random.randn(100)
y = np.random.randn(100)

# Determine the quadrant for each point
quadrants = []
for i in range(len(x)):
    if x[i] > 0 and y[i] > 0:
        quadrants.append('Q1')
    elif x[i] < 0 and y[i] > 0:
        quadrants.append('Q2')
    elif x[i] < 0 and y[i] < 0:
        quadrants.append('Q3')
    else:
        quadrants.append('Q4')

# Create a DataFrame
data = pd.DataFrame({'x': x, 'y': y, 'quadrant': quadrants})

# Create a scatter plot using Seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='x', y='y', hue='quadrant', palette='viridis', s=100)

# Add a legend
plt.legend(title='Quadrants')

# Label the axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Set the title of the plot
plt.title('Quadrant-wise Scatter Plot')

# Display the plot
plt.show()

# %%
#Question 18
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Enable Bokeh output in the notebook
output_notebook()

# Generate the x values
x = np.linspace(0, 4 * np.pi, 100)
# Compute the sine of x
y = np.sin(x)

# Create a new plot with a title and axis labels
p = figure(title='Sine Wave Function', x_axis_label='X-axis', y_axis_label='Y-axis')

# Add a line renderer with legend and line thickness
p.line(x, y, legend_label='Sine Wave', line_width=2)

# Add grid lines
p.grid.grid_line_color = 'black'
p.grid.grid_line_alpha = 0.3

# Show the results
show(p)
# Out:
#   <div id="e1d53635-d327-42e2-92cf-269c1b53ae48" data-root-id="p1049" style="display: contents;"></div>

# %%
#Question 19
import numpy as np
import pandas as pd
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.transform import factor_cmap

# Enable Bokeh output in the notebook
output_notebook()

# Generate random categorical data
categories = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = np.random.randint(10, 100, size=len(categories))

# Create a DataFrame
data = pd.DataFrame({'Category': categories, 'Value': values})

# Create a ColumnDataSource
source = ColumnDataSource(data)

# Define colors for each category based on their values
colors = factor_cmap('Category', palette=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0'], factors=categories)

# Create a new plot with a title and axis labels
p = figure(x_range=categories, height=400, width=600, title='Random Categorical Bar Chart',
           toolbar_location=None, tools='')

# Add a vbar renderer with colors based on values
p.vbar(x='Category', top='Value', width=0.9, source=source, legend_field='Category', line_color='white', fill_color=colors)

# Add hover tooltips to display exact values
hover = HoverTool()
hover.tooltips = [('Category', '@Category'), ('Value', '@Value')]
p.add_tools(hover)

# Label the axes
p.xaxis.axis_label = 'Category'
p.yaxis.axis_label = 'Value'

# Set the title of the plot
p.title.text = 'Random Categorical Bar Chart'

# Display the plot
show(p)
# Out:
#   <div id="f5548a40-caa6-4bc2-8e08-dd3f06e59763" data-root-id="p1108" style="display: contents;"></div>

# %%
#Question 20
import plotly.graph_objects as go
import numpy as np

# Generate a randomly generated dataset
x = np.arange(0, 100)
y = np.random.randn(100)

# Create a line plot
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='lines', name='Random Data'))

# Label the axes
fig.update_layout(xaxis_title='X-axis', yaxis_title='Y-axis')

# Set the title of the plot
fig.update_layout(title='Simple Line Plot')

# Display the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
import numpy as np

# Generate random categorical data
categories = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = np.random.randint(10, 100, size=len(categories))

# Create a pie chart
fig = go.Figure(data=[go.Pie(labels=categories, values=values,
                             hoverinfo='label+percent',
                             textinfo='label+percent',
                             textfont_size=20)])

# Set the title of the pie chart
fig.update_layout(title='Interactive Pie Chart')

# Display the pie chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
